# %% [markdown]
# # Draw a visualization of the cities

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
city_pos = np.genfromtxt("data.txt", delimiter=',')

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(city_pos[:,0], city_pos[:,1])
